# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.model_selection import GridSearchCV

from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, ConfusionMatrixDisplay, roc_auc_score, roc_curve, RocCurveDisplay
from sklearn.metrics import recall_score, precision_score

#from genetic_selection import GeneticSelectionCV
from sklearn_genetic import GAFeatureSelectionCV
from imblearn.over_sampling import SMOTE
import timeit
from tabulate import tabulate
from collections import Counter
from sklearn.ensemble import VotingClassifier

from utilities import evaluation_metrics, scores_table, plot_barchart, plot_roc_auc, grid_search_cv
#pip install sklearn-genetic
#pip install sklearn-genetic-opt
# Out:
# C:\Users\ednac\anaconda3\lib\site-packages\scipy\__init__.py:155: UserWarning: A NumPy version >=1.18.5 and <1.25.0 is required for this version of SciPy (detected version 1.25.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
df = pd.read_csv('creditcard.csv')

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
df.shape
# Out:
# (284807, 31)

# %%
df.describe().T
# Out:
#            count          mean           std         min           25%  \
# Time    284807.0  9.481386e+04  47488.145955    0.000000  54201.500000
# V1      284807.0  1.168375e-15      1.958696  -56.407510     -0.920373
# V2      284807.0  3.416908e-16      1.651309  -72.715728     -0.598550
# V3      284807.0 -1.379537e-15      1.516255  -48.325589     -0.890365
# V4      284807.0  2.074095e-15      1.415869   -5.683171     -0.848640
# V5      284807.0  9.604066e-16      1.380247 -113.743307     -0.691597
# V6      284807.0  1.487313e-15      1.332271  -26.160506     -0.768296
# V7      284807.0 -5.556467e-16      1.237094  -43.557242     -0.554076
# V8      284807.0  1.213481e-16      1.194353  -73.216718     -0.208630
# V9      284807.0 -2.406331e-15      1.098632  -13.434066     -0.643098
# V10     284807.0  2.239053e-15      1.088850  -24.588262     -0.535426
# V11     284807.0  1.673327e-15      1.020713   -4.797473     -0.762494
# V12     284807.0 -1.247012e-15      0.999201  -18.683715     -0.405571
# V13     284807.0  8.190001e-16      0.995274   -5.791881     -0.648539
# V14     284807.0  1.207294e-15      0.958596  -19.214325     -0.425574
# V15     284807.0  4.887456e-15      0.915316   -4.498945     -0.582884
# V16     284807.0  1.437716e-15      0.876253  -14.129855     -0.468037
# V17     284807.0 -3.772171e-16      0.849337  -25.162799     -0.483748
# V18     284807.0  9.564149e-16      0.838176   -9.498746     -0.498850
# V19     284807.0  1.039917e-15      0.814041   -7.213527     -0.456299
# V20     284807.0  6.406204e-16      0.770925  -54.497720     -0.211721
# V21     284807.0  1.654067e-16      0.734524  -34.830382     -0.228395
# V22     284807.0 -3.568593e-16      0.725702  -10.933144     -0.542350
# V23     284807.0  2.578648e-16      0.624460  -44.807735     -0.161846
# V24     284807.0  4.473266e-15      0.605647   -2.836627     -0.354586
# V25     284807.0  5.340915e-16      0.521278  -10.295397     -0.317145
# V26     284807.0  1.683437e-15      0.482227   -2.604551     -0.326984
# V27     284807.0 -3.660091e-16      0.403632  -22.565679     -0.070840
# V28     284807.0 -1.227390e-16      0.330083  -15.430084     -0.052960
# Amount  284807.0  8.834962e+01    250.120109    0.000000      5.600000
# Class   284807.0  1.727486e-03      0.041527    0.000000      0.000000
#
#                  50%            75%            max
# Time    84692.000000  139320.500000  172792.000000
# V1          0.018109       1.315642       2.454930
# V2          0.065486       0.803724      22.057729
# V3          0.179846       1.027196       9.382558
# V4         -0.019847       0.743341      16.875344
# V5         -0.054336       0.611926      34.801666
# V6         -0.274187       0.398565      73.301626
# V7          0.040103       0.570436     120.589494
# V8          0.022358       0.327346      20.007208
# V9         -0.051429       0.597139      15.594995
# V10        -0.092917       0.453923      23.745136
# V11        -0.032757       0.739593      12.018913
# V12         0.140033       0.618238       7.848392
# V13        -0.013568       0.662505       7.126883
# V14         0.050601       0.493150      10.526766
# V15         0.048072       0.648821       8.877742
# V16         0.066413       0.523296      17.315112
# V17        -0.065676       0.399675       9.253526
# V18        -0.003636       0.500807       5.041069
# V19         0.003735       0.458949       5.591971
# V20        -0.062481       0.133041      39.420904
# V21        -0.029450       0.186377      27.202839
# V22         0.006782       0.528554      10.503090
# V23        -0.011193       0.147642      22.528412
# V24         0.040976       0.439527       4.584549
# V25         0.016594       0.350716       7.519589
# V26        -0.052139       0.240952       3.517346
# V27         0.001342       0.091045      31.612198
# V28         0.011244       0.078280      33.847808
# Amount     22.000000      77.165000   25691.160000
# Class       0.000000       0.000000       1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
#  20  V20     284807 non-null  float64
#  21  V21     284807 non-null  float64
#  22  V22     284807 non-null  float64
#  23  V23     284807 non-null  float64
#  24  V24     284807 non-null  float64
#  25  V25     284807 non-null  float64
#  26  V26     284807 non-null  float64
#  27  V27     284807 non-null  float64
#  28  V28     284807 non-null  float64
#  29  Amount  284807 non-null  float64
#  30  Class   284807 non-null  int64
# dtypes: float64(30), int64(1)
# memory usage: 67.4 MB

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 1081

# %%
df = df.drop_duplicates()
df.duplicated().sum()
# Out:
# 0

# %%
print("There are " + str(df.shape[0]) + " attributes and " + str(df.shape[1]) + " features after duplicates have been removed")
# Out:
# There are 283726 attributes and 31 features after duplicates have been removed

# %% [markdown]
# ## EDA

# %%
print("There are" + " " + str(df.Class.nunique()) + " " + "categories in the target class")
print(df.Class.unique())
# Out:
# There are 2 categories in the target class
# [0 1]

# %%
df.Class.value_counts()
# Out:
# Class
# 0    283253
# 1       473
# Name: count, dtype: int64

# %%
df.Class.value_counts(normalize = True)
# Out:
# Class
# 0    0.998333
# 1    0.001667
# Name: proportion, dtype: float64

# %%
# Visualize count of classes

sns.countplot(x=df['Class'], color = 'lightgreen' )
plt.title('Unequally distributed class')
plt.show()

# %%
not_fraud = df['Class'].value_counts(normalize=True)[0]
fraud = df['Class'].value_counts(normalize=True)[1]

# %%
# Visualize classes using pie chart

data = [not_fraud, fraud]
labels = ['not_fraud', 'fraud']
colors = sns.color_palette('pastel')

plt.pie(data, labels = labels, colors = colors, autopct='%1.2f%%', startangle=70)
plt.title('Percentage of classes')
plt.show()

# %% [markdown]
# # Correlation

# %%
df2 = df.drop(columns=['Class'])

# %%
corr_with_class = df2.corrwith(df['Class'])

# %%
corr_with_df = pd.DataFrame(df2.corrwith(df['Class'])).reset_index()
corr_with_df.columns = ['Features', 'Correlation with Class']
corr_with_df = corr_with_df.sort_values(by = 'Correlation with Class')
corr_with_df
# Out:
#    Features  Correlation with Class
# 17      V17               -0.313498
# 14      V14               -0.293375
# 12      V12               -0.250711
# 10      V10               -0.206971
# 16      V16               -0.187186
# 3        V3               -0.182322
# 7        V7               -0.172347
# 18      V18               -0.105340
# 1        V1               -0.094486
# 9        V9               -0.094021
# 5        V5               -0.087812
# 6        V6               -0.043915
# 0      Time               -0.012359
# 24      V24               -0.007210
# 23      V23               -0.006333
# 13      V13               -0.003897
# 15      V15               -0.003300
# 25      V25                0.003202
# 26      V26                0.004265
# 22      V22                0.004887
# 29   Amount                0.005777
# 28      V28                0.009682
# 20      V20                0.021486
# 27      V27                0.021892
# 21      V21                0.026357
# 8        V8                0.033068
# 19      V19                0.033631
# 2        V2                0.084624
# 4        V4                0.129326
# 11      V11                0.149067

# %%
plt.figure(figsize=(12, 4))
plt.stem(corr_with_df['Features'], corr_with_df['Correlation with Class'], orientation = 'vertical')
plt.xticks(rotation=90)
plt.show()

# %%
corr_full = df.corr()
corr_full.head()
# Out:
#           Time        V1        V2        V3        V4        V5        V6  \
# Time  1.000000  0.117927 -0.010556 -0.422054 -0.105845  0.173223 -0.063279
# V1    0.117927  1.000000  0.006875 -0.008112  0.002257 -0.007036  0.000413
# V2   -0.010556  0.006875  1.000000  0.005278 -0.001495  0.005210 -0.000594
# V3   -0.422054 -0.008112  0.005278  1.000000  0.002829 -0.006879 -0.001511
# V4   -0.105845  0.002257 -0.001495  0.002829  1.000000  0.001744 -0.000880
#
#             V7        V8        V9  ...       V21       V22       V23  \
# Time  0.085335 -0.038203 -0.007861  ...  0.045913  0.143727  0.051474
# V1   -0.009173 -0.001168  0.001828  ...  0.002818 -0.001436 -0.001330
# V2    0.007425  0.002899 -0.000274  ... -0.004897  0.001237 -0.003855
# V3   -0.011721 -0.001815 -0.003579  ...  0.003500 -0.000275  0.000449
# V4    0.004657  0.000890  0.002154  ... -0.001034  0.000115  0.000732
#
#            V24       V25       V26       V27       V28    Amount     Class
# Time -0.015954 -0.233262 -0.041818 -0.005171 -0.009305 -0.010559 -0.012359
# V1   -0.000723 -0.000222 -0.000684 -0.015706 -0.004861 -0.230105 -0.094486
# V2    0.000701 -0.001569  0.000253  0.007555  0.001611 -0.533428  0.084624
# V3   -0.000072  0.000425 -0.000094 -0.007051 -0.000134 -0.212410 -0.182322
# V4   -0.000120  0.000162  0.000777  0.001322  0.000231  0.099514  0.129326
#
# [5 rows x 31 columns]

# %%
f, ax = plt.subplots(figsize=(15, 10))
mask = np.triu(np.ones_like(corr_full, dtype=bool))
cmap = "coolwarm"
sns.heatmap(corr_full, mask=mask, vmax=1,cmap=cmap, center=0, square=True, linewidths=.5)
#annot = True,
plt.show()

# %%
df['Class']
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 284802    0
# 284803    0
# 284804    0
# 284805    0
# 284806    0
# Name: Class, Length: 283726, dtype: int64

# %% [markdown]
# # DETECTING OUTLIER

# %%
#sns.violinplot(data = df.iloc[:, 1:6])
#sns.violinplot(data = df.iloc[:, 6:11])
#sns.violinplot(data = df.iloc[:, 11:16])
#sns.violinplot(data = df.iloc[:, 16:21])
#sns.violinplot(data = df.iloc[:, 21:26])
#sns.violinplot(data = df.iloc[:, 26:29])

#plt.plot()

# %% [markdown]
# # SETTING UP VALIDATION FRAMEWORK

# %%
# Split data into train, validation, test
from sklearn.model_selection import train_test_split

df_full_train, df_test = train_test_split(df, test_size=0.2, random_state=1)
df_train, df_val = train_test_split(df_full_train, test_size=0.25, random_state=1)

# %%
len(df_full_train), len(df_train), len(df_val), len(df_test)
# Out:
# (226980, 170235, 56745, 56746)

# %%
df_full_train = df_full_train.reset_index(drop=True)
df_train = df_train.reset_index(drop=True)
df_val = df_val.reset_index(drop=True)
df_test = df_test.reset_index(drop=True)

y_train = df_train['Class'].values
y_val = df_val['Class'].values
y_test = df_test['Class'].values


del df_train['Class']
del df_val['Class']
del df_test['Class']

df_full = df_full_train.copy()
y_full = df_full['Class']

del df_full['Class']

# %%
df_full = df_full.copy
df_train_copy = df_train.copy()
df_val_copy = df_val.copy()
df_test_copy = df_test.copy()

y_full_copy = y_full.copy()
y_train_copy = y_train.copy()
y_val_copy = y_val.copy()
y_test_copy = y_test.copy()

# %% [markdown]
# ## BASE MODELS - WITHOUT FEATURE SELECTION OR OVERSAMPLING

# %%
models = [
    LogisticRegression(random_state=42),
    SVC(random_state=42, probability=True),
    GaussianNB(),
    RandomForestClassifier(random_state=42),
    XGBClassifier(random_state=42)
    ]

model_names = [
    'Logistic Regression',
    'SVM',
    'Gaussian Naive Bayes',
    'Random Forest',
    'XGBoost'
    ]

# %% [markdown]
# ## TRAINING PIPELINE WITH FEATURE SCALING
#
# ### STANDARDIZATION

# %%
pipelines = []

for model in models:
  pipe = Pipeline([
      ('scaler', StandardScaler()),
      ('classifier', model)
      ])
  pipelines.append(pipe)

# %%
pipelines
# Out:
# [Pipeline(steps=[('scaler', StandardScaler()),
#                  ('classifier', LogisticRegression(random_state=42))]),
#  Pipeline(steps=[('scaler', StandardScaler()),
#                  ('classifier', SVC(probability=True, random_state=42))]),
#  Pipeline(steps=[('scaler', StandardScaler()), ('classifier', GaussianNB())]),
#  Pipeline(steps=[('scaler', StandardScaler()),
#                  ('classifier', RandomForestClassifier(random_state=42))]),
#  Pipeline(steps=[('scaler', StandardScaler()),
#                  ('classifier',
#                   XGBClassifier(base_score=None, booster=None, callbacks=None,
#                                 colsample_bylevel=None, colsample_bynode=None,
#                                 colsample_bytree=None,
#                                 early_stopping_rounds=None,
#                                 enable_categorical=False, eval_metric=None,
#                                 feature_types=None, gamma=None, gpu_id=None,
#                                 grow_policy=None, importance_type=None,
#                                 interaction_constraints=None, learning_rate=None,
#                                 max_bin=None, max_cat_threshold=None,
#                                 max_cat_to_onehot=None, max_delta_step=None,
#                                 max_depth=None, max_leaves=None,
#                                 min_child_weight=None, missing=nan,
#                                 monotone_constraints=None, n_estimators=100,
#                                 n_jobs=None, num_parallel_tree=None,
#                                 predictor=None, random_state=42, ...))])]

# %% [markdown]
# ## TRAINING AND EVALUATION ON VALIDATION SET

# %%
# Lists to store evaluation metrics across models
all_accuracy = []
all_recall = []
all_precision = []
all_roc_auc = []
all_fpr = []
all_tpr = []

# %%
# Train and evaluate each model using the pipelines

for model_name, pipeline in zip(model_names, pipelines):

  # Time the training process
  training_time = timeit.timeit(
      stmt = '''pipeline.fit(df_train, y_train)''',
      globals = globals(), number = 1
      )

  # Print the training time for the current classifier
  print(f"Time taken to train {model_name}: {training_time:.2f} seconds")

  # Evaluate model
  accuracy, recall, precision, roc_auc_Score, fpr, tpr = evaluation_metrics(pipeline, df_val, y_val, model_name, labels)

  all_accuracy.append(accuracy)
  all_recall.append(recall)
  all_precision.append(precision)
  all_roc_auc.append(roc_auc_Score)
  all_fpr.append(fpr)
  all_tpr.append(tpr)
  print('===================================================================================')
# Out:
# Time taken to train Logistic Regression: 2.48 seconds
# Classifier: Logistic Regression
# Accuracy: 0.999
#
#
# Classification Report:
#                precision    recall  f1-score   support
#
#    not_fraud       1.00      1.00      1.00     56638
#        fraud       0.90      0.58      0.70       107
#
#     accuracy                           1.00     56745
#    macro avg       0.95      0.79      0.85     56745
# weighted avg       1.00      1.00      1.00     56745
# ROC AUC Score: 0.97
# ===================================================================================
# Time taken to train SVM: 1767.96 seconds
# Classifier: SVM
# Accuracy: 0.999
#
#
# Classification Report:
#                precision    recall  f1-score   support
#
#    not_fraud       1.00      1.00      1.00     56638
#        fraud       0.92      0.63      0.74       107
#
#     accuracy                           1.00     56745
#    macro avg       0.96      0.81      0.87     56745
# weighted avg       1.00      1.00      1.00     56745
# ROC AUC Score: 0.94
# ===================================================================================
# Time taken to train Gaussian Naive Bayes: 0.33 seconds
# Classifier: Gaussian Naive Bayes
# Accuracy: 0.977
#
#
# Classification Report:
#                precision    recall  f1-score   support
#
#    not_fraud       1.00      0.98      0.99     56638
#        fraud       0.06      0.81      0.12       107
#
#     accuracy                           0.98     56745
#    macro avg       0.53      0.90      0.55     56745
# weighted avg       1.00      0.98      0.99     56745
# ROC AUC Score: 0.97
# ===================================================================================
# Time taken to train Random Forest: 642.92 seconds
# Classifier: Random Forest
# Accuracy: 0.999
#
#
# Classification Report:
#                precision    recall  f1-score   support
#
#    not_fraud       1.00      1.00      1.00     56638
#        fraud       0.94      0.73      0.82       107
#
#     accuracy                           1.00     56745
#    macro avg       0.97      0.86      0.91     56745
# weighted avg       1.00      1.00      1.00     56745
# ROC AUC Score: 0.95
# ===================================================================================
# Time taken to train XGBoost: 29.19 seconds
# Classifier: XGBoost
# Accuracy: 1.000
#
#
# Classification Report:
#                precision    recall  f1-score   support
#
#    not_fraud       1.00      1.00      1.00     56638
#        fraud       0.95      0.78      0.86       107
#
#     accuracy                           1.00     56745
#    macro avg       0.98      0.89      0.93     56745
# weighted avg       1.00      1.00      1.00     56745
# ROC AUC Score: 0.98
# ===================================================================================

# %%
scores_table(model_names, all_accuracy, all_recall, all_roc_auc, 'Model Performance - Base')
# Out:
# Model Performance - Base
#
# +----------------------+------------+----------+-----------+
# | Models               |   Accuracy |   Recall |   ROC_AUC |
# +======================+============+==========+===========+
# | Logistic Regression  |   0.999084 | 0.579439 |  0.971696 |
# +----------------------+------------+----------+-----------+
# | SVM                  |   0.999189 | 0.626168 |  0.936735 |
# +----------------------+------------+----------+-----------+
# | Gaussian Naive Bayes |   0.976985 | 0.813084 |  0.96573  |
# +----------------------+------------+----------+-----------+
# | Random Forest        |   0.999401 | 0.728972 |  0.947208 |
# +----------------------+------------+----------+-----------+
# | XGBoost              |   0.999507 | 0.775701 |  0.975079 |
# +----------------------+------------+----------+-----------+

# %%
plot_barchart(model_names, all_accuracy, 'Accuracy', 'Accuracy Comparison - Base')

# %%
plot_barchart(model_names, all_recall, 'Recall', 'Recall Comparison - Base')

# %%
plot_roc_auc(model_names, all_fpr, all_tpr, all_roc_auc, 'ROC AUC CURVES - Base')

# %% [markdown]
# # TRAINING WITH FEATURE SELECTION AND CLASS BALANCING

# %% [markdown]
# ## THE GENECTIC ALGORITHIM FOR FEATURE SELECTION

# %%
estimator = RandomForestClassifier(random_state=42)

evolved_estimator = GAFeatureSelectionCV(
    estimator=estimator,
    cv=2,
    scoring="accuracy",
    population_size=10,
    generations=10,
    n_jobs=-1,
    elitism=True,
    max_features=None,
    verbose=True,
)

# %%
evolved_estimator.fit(df_train_copy, y_train_copy)
evolved_estimator.best_features_
# Out:
# gen	nevals	fitness 	fitness_std	fitness_max	fitness_min
# 0  	10    	0.999367	0.000118306	0.999495   	0.999078
# 1  	20    	0.999451	4.40569e-05	0.999495   	0.999383
# 2  	20    	0.999475	1.66563e-05	0.999512   	0.999454
# 3  	20    	0.999452	4.45087e-05	0.999512   	0.999348
# 4  	20    	0.999477	1.801e-05  	0.999512   	0.999454
# 5  	20    	0.999455	2.94943e-05	0.999489   	0.999407
# 6  	20    	0.999478	1.18799e-05	0.999489   	0.99946
# 7  	20    	0.999481	1.05736e-05	0.999489   	0.99946
# 8  	20    	0.999489	4.14079e-11	0.999489   	0.999489
# 9  	20    	0.999487	7.45359e-06	0.999495   	0.999465
# 10 	20    	0.999482	1.9385e-05 	0.999489   	0.999424
# array([False, False, False, False,  True, False, False,  True, False,
#        False,  True, False,  True, False,  True, False,  True,  True,
#        False, False, False,  True, False, False,  True, False, False,
#        False,  True,  True])

# %%
selected_features = evolved_estimator.get_feature_names_out(input_features=df_train_copy.columns)
selected_features
# Out:
# array(['V4', 'V7', 'V10', 'V12', 'V14', 'V16', 'V17', 'V21', 'V24', 'V28',
#        'Amount'], dtype=object)

# %% [markdown]
# ## Filter the data to include only the selected features

# %%
df_train_selected = df_train_copy.loc[:, selected_features]
df_val_selected = df_val_copy.loc[:, selected_features]
df_test_selected = df_test_copy.loc[:, selected_features]

df_train_selected.head()
# Out:
#          V4        V7       V10       V12       V14       V16       V17  \
# 0  1.681259  0.937822 -0.116385 -0.523544  0.987795  0.084641 -0.136063
# 1  0.297820 -2.571801  1.269865  1.598242  0.587305  0.124582 -0.352808
# 2  0.083840  0.816489  0.024556  0.111034  0.875725 -0.634152 -0.230492
# 3  1.496151  0.298420 -0.209503  0.911417 -0.044924 -0.736753  0.225039
# 4  2.810175  2.216271  0.779595 -0.332759  0.045206  0.471108 -0.643196
#
#         V21       V24       V28  Amount
# 0 -0.112173  0.631496  0.103991  465.00
# 1 -0.385840  0.635952  0.315491    6.01
# 2  0.153164  0.098628 -0.077090   16.37
# 3 -0.010828  0.115813  0.041414  145.67
# 4  0.036636  0.401559 -0.302437  239.00

# %%
df_train_selected.shape
# Out:
# (170235, 11)

# %%
Counter(y_train_copy)
# Out:
# Counter({0: 169956, 1: 279})

# %%
y_train_copy
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %% [markdown]
# ## SOLVING IMBALANCE PROBLEM - OVERSAMPLING

# %%
sm = SMOTE(random_state=0)

df_selected_oversampled, y_selected_oversampled = sm.fit_resample(df_train_selected, y_train_copy)

# %%
Counter(y_selected_oversampled)
# Out:
# Counter({0: 169956, 1: 169956})

# %%
df_selected_oversampled.shape
# Out:
# (339912, 11)

# %%
df_val_selected_oversampled, y_val_selected_oversampled = sm.fit_resample(df_val_selected, y_val_copy)
df_test_selected_oversampled, y_test_selected_oversampled= sm.fit_resample(df_test_selected, y_test_copy)

# %%
df_val_selected_oversampled.shape
# Out:
# (113276, 11)

# %% [markdown]
# ## TRAINING AND EVALUATION ON VALIDATION SET WITH FILTERED DATA

# %%
all_accuracy_ga_sm = []
all_recall_ga_sm = []
all_precision_ga_sm = []
all_roc_auc_ga_sm = []
all_fpr_ga_sm =[]
all_tpr_ga_sm = []

# %%
# Train and evaluate each model using the pipelines

for model_name, pipeline_ga_sm in zip(model_names, pipelines):

  # Time the training process
  training_time = timeit.timeit(
      stmt = '''pipeline_ga_sm.fit(df_selected_oversampled, y_selected_oversampled)''',
      globals = globals(), number = 1
      )

  # Print the training time for the current classifier
  print(f"Time taken to train {model_name}: {training_time:.2f} seconds")

  # Evaluate model
  accuracy, recall, precision, roc_auc_Score, fpr, tpr = evaluation_metrics(pipeline_ga_sm, df_val_selected_oversampled, y_val_selected_oversampled, model_name, labels)
    

  all_accuracy_ga_sm.append(accuracy)
  all_recall_ga_sm.append(recall)
  all_precision_ga_sm.append(precision)
  all_roc_auc_ga_sm.append(roc_auc_Score)
  all_fpr_ga_sm.append(fpr)
  all_tpr_ga_sm.append(tpr)
  print('===================================================================================')
# Out:
# Time taken to train Logistic Regression: 0.90 seconds
# Classifier: Logistic Regression
# Accuracy: 0.947
#
#
# Classification Report:
#                precision    recall  f1-score   support
#
#    not_fraud       0.92      0.98      0.95     56638
#        fraud       0.98      0.91      0.95     56638
#
#     accuracy                           0.95    113276
#    macro avg       0.95      0.95      0.95    113276
# weighted avg       0.95      0.95      0.95    113276
# ROC AUC Score: 0.99
# ===================================================================================
# Time taken to train SVM: 4427.91 seconds
# Classifier: SVM
# Accuracy: 0.944
#
#
# Classification Report:
#                precision    recall  f1-score   support
#
#    not_fraud       0.91      0.99      0.95     56638
#        fraud       0.99      0.90      0.94     56638
#
#     accuracy                           0.94    113276
#    macro avg       0.95      0.94      0.94    113276
# weighted avg       0.95      0.94      0.94    113276
# ROC AUC Score: 0.97
# ===================================================================================
# Time taken to train Gaussian Naive Bayes: 0.15 seconds
# Classifier: Gaussian Naive Bayes
# Accuracy: 0.932
#
#
# Classification Report:
#                precision    recall  f1-score   support
#
#    not_fraud       0.90      0.98      0.93     56638
#        fraud       0.98      0.89      0.93     56638
#
#     accuracy                           0.93    113276
#    macro avg       0.94      0.93      0.93    113276
# weighted avg       0.94      0.93      0.93    113276
# ROC AUC Score: 0.98
# ===================================================================================
# Time taken to train Random Forest: 256.18 seconds
# Classifier: Random Forest
# Accuracy: 0.939
#
#
# Classification Report:
#                precision    recall  f1-score   support
#
#    not_fraud       0.89      1.00      0.94     56638
#        fraud       1.00      0.88      0.94     56638
#
#     accuracy                           0.94    113276
#    macro avg       0.95      0.94      0.94    113276
# weighted avg       0.95      0.94      0.94    113276
# ROC AUC Score: 0.98
# ===================================================================================
# Time taken to train XGBoost: 28.48 seconds
# Classifier: XGBoost
# Accuracy: 0.945
#
#
# Classification Report:
#                precision    recall  f1-score   support
#
#    not_fraud       0.90      1.00      0.95     56638
#        fraud       1.00      0.89      0.94     56638
#
#     accuracy                           0.94    113276
#    macro avg       0.95      0.94      0.94    113276
# weighted avg       0.95      0.94      0.94    113276
# ROC AUC Score: 0.99
# ===================================================================================

# %%
scores_table(model_names, all_accuracy_ga_sm, all_recall_ga_sm, all_roc_auc_ga_sm, 'Model Performance - GA + SM')
# Out:
# Model Performance - GA + SM
#
# +----------------------+------------+----------+-----------+
# | Models               |   Accuracy |   Recall |   ROC_AUC |
# +======================+============+==========+===========+
# | Logistic Regression  |   0.946988 | 0.913468 |  0.986903 |
# +----------------------+------------+----------+-----------+
# | SVM                  |   0.944331 | 0.900067 |  0.971477 |
# +----------------------+------------+----------+-----------+
# | Gaussian Naive Bayes |   0.931804 | 0.886119 |  0.978212 |
# +----------------------+------------+----------+-----------+
# | Random Forest        |   0.938972 | 0.878244 |  0.981145 |
# +----------------------+------------+----------+-----------+
# | XGBoost              |   0.94486  | 0.890339 |  0.985523 |
# +----------------------+------------+----------+-----------+

# %%
plot_barchart(model_names, all_accuracy_ga_sm, 'Accuracy', 'Accuracy Comparison - GA + SM')

# %%
plot_barchart(model_names, all_recall_ga_sm, 'Recall', 'Recall Comparison - GA + SM')

# %%
plot_roc_auc(model_names, all_fpr_ga_sm, all_tpr_ga_sm, all_roc_auc_ga_sm, 'ROC AUC CURVES - GA + SM')

# %% [markdown]
# ## DEFINE PARAMETERS

# %%
# Logistic Regression
param_grid_lr = {
    'C': np.logspace(-4, 2, 7),
}

# Support Vector Machines
param_grid_svm = {
    'C': [0.01, 0.1, 1],
    'kernel': ['linear', 'rbf', 'poly'],
    }

# Naive Bayes
param_grid_gnb = {
    'var_smoothing': [1e-9, 1e-8, 1e-7],
}

# Random Forest
param_grid_rf = {
    'n_estimators': [10, 100, 1000],
    'max_depth': [None, 10, 100],
}

# XGBoost
param_grid_xgb = {
    'eta': [0.01, 0.1, 0.3],
    'max_depth': [2, 4, 6],
    'gamma': [0, 0.1, 1],
}

# %%
param_grids = [
    param_grid_lr,
    param_grid_svm,
    param_grid_gnb,
    param_grid_rf,
    param_grid_xgb
    ]

# %% [markdown]
# ## FUNCTION FOR HYPERPARAMETER OPTIMIZATION

# %%
# def grid_search_cv(X_train, y_train, models, param_grids, cv=3):
#   best_models = []
#   best_scores = []

#   # Initialize StandardScaler
#   scaler = StandardScaler()
#   X_train_scaled = scaler.fit_transform(X_train)

#   for model, param_grid in zip(models, param_grids):
#     grid_search = GridSearchCV(model, param_grid, cv=3, n_jobs=-1, verbose=2)

#     grid_search.fit(X_train_scaled, y_train)

#     best_models.append(grid_search.best_estimator_)
#     best_scores.append(grid_search.best_score_)

#   return best_models, best_scores

# %%
best_models, best_scores = grid_search_cv(df_selected_oversampled, y_selected_oversampled, models, param_grids)
# Out:
# Fitting 3 folds for each of 7 candidates, totalling 21 fits
# Fitting 3 folds for each of 9 candidates, totalling 27 fits

# %%
best_models

# %%
best_scores

# %% [markdown]
# # TRAINING AND EVALUATION WITH OPTIMIZED HYPERPARAMETER

# %%
grid_models = [
    LogisticRegression(random_state=42),
    SVC(random_state=42, probability=True),
    GaussianNB(),
    RandomForestClassifier(random_state=42),
    XGBClassifier(random_state=42)
    ]

# %%
grid_pipelines = []

for model in grid_models:
  pipe = Pipeline([
      ('scaler', StandardScaler()),
      ('classifier', model)
      ])
  grid_pipelines.append(pipe)

# %%
# Lists to store evaluation metrics across models
grid_accuracy = []
grid_recall = []
grid_precision = []
grid_roc_auc = []
grid_fpr = []
grid_tpr = []

# %%
# Train and evaluate each model using the pipelines

for model_name, grid_pipeline in zip(model_names, grid_pipelines):

  # Time the training process
  training_time = timeit.timeit(
      stmt = '''grid_pipeline.fit(df_selected_oversampled, y_selected_oversampled)''',
      globals = globals(), number = 1
      )

  # Print the training time for the current classifier
  print(f"Time taken to train {model_name}: {training_time:.2f} seconds")

  # Evaluate model
  accuracy, recall, precision, roc_auc_Score, fpr, tpr = evaluation_metrics(grid_pipeline, df_val_selected_oversampled, y_val_selected_oversampled, model_name, labels)

  grid_accuracy.append(accuracy)
  grid_recall.append(recall)
  grid_precision.append(precision)
  grid_roc_auc.append(roc_auc_Score)
  grid_fpr.append(fpr)
  grid_tpr.append(tpr)
  print('===================================================================================')

# %%
scores_table(model_names, grid_accuracy, grid_recall, grid_roc_auc, 'Model Performance - GA + SM + HO')

# %%
plot_barchart(model_names, grid_accuracy, 'Accuracy', 'Accuracy Comparison - GA + SM + HO')

# %%
plot_barchart(model_names, grid_recall, 'Recall', 'Recall Comparison - GA + SM + HO')

# %%
plot_roc_auc(model_names, grid_fpr, grid_tpr, grid_roc_auc, 'ROC AUC CURVES - GA + SM + HO')

# %% [markdown]
# # ENSEMBLE LEARNING AND HYPERPARAMETER OPTIMIZATION

# %%
lr = LogisticRegression(random_state=42),
svc = SVC(random_state=42, probability=True),
gnb = GaussianNB(),
rf = RandomForestClassifier(random_state=42),
xgb = XGBClassifier(random_state=42)

estimators = [
    ('lr', lr),
    ('svc', svc), 
    ('gnb', gnb), 
    ('rf', rf), 
    ('xgb', xgb)
]

# %%
ensemble_clf = VotingClassifier(
    estimators = estimators,
    voting = 'soft',
    n_jobs = -1,
    verbose= True
)

# %%
ensemble_clf.fit(df_selected_oversampled, y_selected_oversampled)
#ensemble_clf.predict(X)
accuracy, recall, precision, roc_auc_Score, fpr, tpr = evaluation_metrics(ensemble_clf, df_val_selected_oversampled, y_val_selected_oversampled, 'Ensemble Learning', )
